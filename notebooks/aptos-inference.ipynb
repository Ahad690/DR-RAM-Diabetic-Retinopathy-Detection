# %%
# 1. Clone the repository
# !git clone https://github.com/Ahad690/DR-RAM-Diabetic-Retinopathy-Detection.git

# 2. Enter the directory
# %cd DR-RAM-Diabetic-Retinopathy-Detection

# 3. Install all requirements (takes about 1-2 mins)
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'DR-RAM-Diabetic-Retinopathy-Detection'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 72 (delta 9), reused 34 (delta 6), pack-reused 33 (from 1)
# Receiving objects: 100% (72/72), 64.76 MiB | 23.20 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /kaggle/working/DR-RAM-Diabetic-Retinopathy-Detection/DR-RAM-Diabetic-Retinopathy-Detection/DR-RAM-Diabetic-Retinopathy-Detection/DR-RAM-Diabetic-Retinopathy-Detection

# %%
# 4. Run the inference script
# !python notebooks/inference.py

# 5. Show the result immediately
from IPython.display import Image, display
display(Image('prediction_result.png'))
# Out:
# ============================================================
# DR-RAM: Diabetic Retinopathy Detection
# Loading Pre-trained Model and Running Inference
# ============================================================
# Selecting random image: 021c207614d6.png
#
# Device: cpu
#
# [1/4] Loading model...
# Creating model architecture...
# Loading weights from: results/checkpoints/drram_best.pth
# ✅ Model loaded successfully!
#    Parameters: 7,634,436
#
# [2/4] Preprocessing image...
#    Image shape: torch.Size([1, 3, 380, 380])
#
# [3/4] Running inference...
#
# ========================================
# PREDICTION RESULTS
# ========================================
# Predicted Class: 2 (Moderate)
# Confidence: 84.56%
#
# All Probabilities:
#     No DR: 0.0014
#     Mild: 0.0760
#   → Moderate: 0.8456
#     Severe: 0.0651
#     Proliferative DR: 0.0119
#
# [4/4] Generating visualization...
# Figure saved to: prediction_result.png
# Figure(1800x600)
#
# ✅ Inference complete!
